# %%
#!/usr/bin/python3
# Simple TicTacToe game in Python - EAO
#In this game, you will be required to fill in the missing bits and commit you code weekly
# Please fill in the missing prompts every week as directed

#WEEK 1
import random
import sys

board=[i for i in range(0,9)]
player, computer = '',''

# Corners, Center and Others, respectively
moves=((1,7,3,9),(5,),(2,4,6,8))
# Winner combinations - think about what combinations will make you WIN the game!!
winners=((?,?,?),(?,?,?),(?,?,?), (?,?,?), (?,?,?), (?,?,?), (?,?,?), (?,?,?)) 
# Table
tab=range(1,10)

# %%
#WEEK 1
#snippet to print the board
def print_board():
    x=??  #think about what value can variable x have, Hint: Integer
    for i in board:
        end = ' | '
        if x%3 == 0:
            end = ' \n'
            if i != 1: end+='---------\n';
        char=' '
        if i in ('??','??'): char=i;  #Think about what values do we will the grid with
        x+=??                         #what value will x increment each time
        print(char,end=end)
print_board()

# %%
#WEEK 2
def select_char():
    chars=('??','??')
    if random.randint(??,??) == 0: #what random values can we have, hint: Integer
        return chars[::-1]
    return chars

def can_move(brd, player, move):
    if move in tab and brd[move-1] == move-1:
        return ??        #Hint: BOOLEAN value
    return ??            #Hint: BOOLEAN value

def can_win(brd, player, move):
    places=[]
    x=0
    for i in brd:
        if i == player: places.append(x);
        x+=1
    win=??    #Hint: BOOLEAN Value
    for tup in winners:
        win=?? #Hint: BOOLEAN Value
        for ix in tup:
            if brd[ix] != player:
                win=??    #Hint: BOOLEAN Value
                break 
        if win == ??:     #Hint: BOOLEAN Value
            break
    return win

# %%
#WEEK 3
def make_move(brd, player, move, undo=False):
    if can_move(??, ??, ??):    #Hint: Look at arguments of can_move
        brd[move-1] = player
        win=can_win(brd, player, move)
        if undo:
            brd[move-1] = move-1
        return (True, win)
    return (False, False)

# AI goes here
def computer_move():
    move=??    #Tricky, don't worry (Hint: Negative INTEGER)
    # If I can win, others don't matter.
    for i in range(1,10):
        if make_move(board, computer, i, True)[1]:
            move=?? #Hint, what is your counter again?
            break
    if move == ??: #What did you initialize move with?
        # If player can win, block him.
        for i in range(1,10):
            if make_move(board, player, i, True)[1]:
                move=??  #Hint, what is your counter again?
                break
    if move == ??: #What did you initialize move with?
        # Otherwise, try to take one of desired places.
        for tup in moves:
            for mv in tup:
                if move == -1 and can_move(board, computer, mv):
                    move=mv
                    break
    return make_move(board, computer, move)

def space_exist():
    return board.count('X') + board.count('O') != 9

# %%
#WEEK 4
player, computer = select_char()


print('Player is [%s] and computer is [%s]' % (??, ??))  #Hint: Re read the print statement
result='%%% Deuce ! %%%'
while space_exist():
    ??  #Call print board function
    print('# Make your move ! [1-9] : ', end='')
    move = int(input())
    moved, won = make_move(??, ??, ??)   #Look at the arguments of the make move function
    if not moved:
        print(' >> Invalid number ! Try again !')
        continue
    #
    if won:
        result='*** Congratulations ! You won ! ***'
        break
    elif computer_move()[1]:
        result='=== You lose ! =='
        break;

?? #Call print board function
?? #Print the result
